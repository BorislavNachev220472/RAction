# %%
import torch

print(torch.cuda.is_available())
# Out:
# True

# %%
data = {
'nnUNet_raw':'/workspace/2024-25ab-fai3-specialisation-project-team-specifix-1/data/segmentation/nnUNet_raw',
'nnUNet_preprocessed':'/workspace/2024-25ab-fai3-specialisation-project-team-specifix-1/data/segmentation/nnUNet_preprocessed',
'nnUNet_results':'/workspace/2024-25ab-fai3-specialisation-project-team-specifix-1/data/segmentation/nnUNet_results'
}

with open('.env', 'w') as file:
    for key in data:
        file.write(f'{key}={data[key]}\n')

with open('.env', 'r') as file:
    cf = file.read()
print(cf)
# Out:
# nnUNet_raw=/workspace/2024-25ab-fai3-specialisation-project-team-specifix-1/data/segmentation/nnUNet_raw
# nnUNet_preprocessed=/workspace/2024-25ab-fai3-specialisation-project-team-specifix-1/data/segmentation/nnUNet_preprocessed
# nnUNet_results=/workspace/2024-25ab-fai3-specialisation-project-team-specifix-1/data/segmentation/nnUNet_results

# %%
import os
from dotenv import load_dotenv
import subprocess
 
   # Load environment variables from .env file
load_dotenv(override=True)
# Out:
# True

# %%
# !poetry run nnUNetv2_plan_and_preprocess -d 063 --verify_dataset_integrity -c 3d_fullres
# Out:
# Fingerprint extraction...
# Dataset063_M_h2
# Using <class 'nnunetv2.imageio.simpleitk_reader_writer.SimpleITKIO'> as reader/writer
#
# ####################
# verify_dataset_integrity Done.
# If you didn't see any error messages then your dataset is most likely OK!
# ####################
#
# Using <class 'nnunetv2.imageio.simpleitk_reader_writer.SimpleITKIO'> as reader/writer
# 100%|███████████████████████████████████████████| 58/58 [01:30<00:00,  1.57s/it]
# Experiment planning...
# Attempting to find 3d_lowres config.
# Current spacing: [0.61799996 0.36009766 0.36009766].
# Current patch size: [128 112 160].
# Current median shape: [497.08737864 497.08737864 692.7184466 ]
# Attempting to find 3d_lowres config.
# Current spacing: [0.63653996 0.37090059 0.37090059].
# Current patch size: [128 112 160].
# Current median shape: [482.60910548 482.60910548 672.54218117]
# Attempting to find 3d_lowres config.
# Current spacing: [0.65563616 0.3820276  0.3820276 ].
# Current patch size: [128 112 160].
# Current median shape: [468.55252959 468.55252959 652.95357395]
# Attempting to find 3d_lowres config.
# Current spacing: [0.67530525 0.39348843 0.39348843].
# Current patch size: [128 112 160].
# Current median shape: [454.90536853 454.90536853 633.93550869]
# Attempting to find 3d_lowres config.
# Current spacing: [0.6955644  0.40529308 0.40529308].
# Current patch size: [128 112 160].
# Current median shape: [441.6556976  441.6556976  615.47136766]
# Attempting to find 3d_lowres config.
# Current spacing: [0.71643134 0.41745188 0.41745188].
# Current patch size: [128 112 160].
# Current median shape: [428.79193942 428.79193942 597.54501714]
# Attempting to find 3d_lowres config.
# Current spacing: [0.73792428 0.42997543 0.42997543].
# Current patch size: [128 112 160].
# Current median shape: [416.30285381 416.30285381 580.14079334]
# Attempting to find 3d_lowres config.
# Current spacing: [0.760062  0.4428747 0.4428747].
# Current patch size: [128 112 160].
# Current median shape: [404.17752797 404.17752797 563.24348868]
# Attempting to find 3d_lowres config.
# Current spacing: [0.78286386 0.45616094 0.45616094].
# Current patch size: [128 112 160].
# Current median shape: [392.40536696 392.40536696 546.83833853]
# Attempting to find 3d_lowres config.
# Current spacing: [0.80634978 0.46984577 0.46984577].
# Current patch size: [128 112 160].
# Current median shape: [380.97608443 380.97608443 530.91100828]
# Attempting to find 3d_lowres config.
# Current spacing: [0.83054027 0.48394114 0.48394114].
# Current patch size: [128 112 160].
# Current median shape: [369.87969362 369.87969362 515.44758085]
# Attempting to find 3d_lowres config.
# Current spacing: [0.85545648 0.49845937 0.49845937].
# Current patch size: [128 112 160].
# Current median shape: [359.10649866 359.10649866 500.43454452]
# Attempting to find 3d_lowres config.
# Current spacing: [0.88112018 0.51341315 0.51341315].
# Current patch size: [128 112 160].
# Current median shape: [348.64708608 348.64708608 485.85878109]
# Attempting to find 3d_lowres config.
# Current spacing: [0.90755378 0.52881555 0.52881555].
# Current patch size: [128 112 160].
# Current median shape: [338.49231658 338.49231658 471.70755445]
# Attempting to find 3d_lowres config.
# Current spacing: [0.93478039 0.54468001 0.54468001].
# Current patch size: [128 112 160].
# Current median shape: [328.63331707 328.63331707 457.96849947]
# Attempting to find 3d_lowres config.
# Current spacing: [0.96282381 0.56102042 0.56102042].
# Current patch size: [128 112 160].
# Current median shape: [319.06147288 319.06147288 444.62961113]
# Attempting to find 3d_lowres config.
# Current spacing: [0.99170852 0.57785103 0.57785103].
# Current patch size: [128 112 160].
# Current median shape: [309.76842027 309.76842027 431.67923411]
# Attempting to find 3d_lowres config.
# Current spacing: [1.02145978 0.59518656 0.59518656].
# Current patch size: [128 112 160].
# Current median shape: [300.7460391  300.7460391  419.10605253]
# Attempting to find 3d_lowres config.
# Current spacing: [1.05210357 0.61304216 0.61304216].
# Current patch size: [128 112 160].
# Current median shape: [291.98644573 291.98644573 406.89908013]
# Attempting to find 3d_lowres config.
# Current spacing: [1.08366668 0.63143342 0.63143342].
# Current patch size: [128 112 160].
# Current median shape: [283.48198614 283.48198614 395.04765061]
# Attempting to find 3d_lowres config.
# Current spacing: [1.11617668 0.65037642 0.65037642].
# Current patch size: [128 112 160].
# Current median shape: [275.22522927 275.22522927 383.54140836]
# Attempting to find 3d_lowres config.
# Current spacing: [1.14966198 0.66988772 0.66988772].
# Current patch size: [128 112 160].
# Current median shape: [267.20896045 267.20896045 372.37029938]
# Attempting to find 3d_lowres config.
# Current spacing: [1.18415184 0.68998435 0.68998435].
# Current patch size: [128 112 160].
# Current median shape: [259.4261752 259.4261752 361.5245625]
# Attempting to find 3d_lowres config.
# Current spacing: [1.21967639 0.71068388 0.71068388].
# Current patch size: [128 112 160].
# Current median shape: [251.87007301 251.87007301 350.99472088]
# Attempting to find 3d_lowres config.
# Current spacing: [1.25626668 0.73200439 0.73200439].
# Current patch size: [128 112 160].
# Current median shape: [244.53405146 244.53405146 340.77157367]
# Attempting to find 3d_lowres config.
# Current spacing: [1.29395468 0.75396453 0.75396453].
# Current patch size: [128 112 160].
# Current median shape: [237.41170045 237.41170045 330.84618803]
# Attempting to find 3d_lowres config.
# Current spacing: [1.33277332 0.77658346 0.77658346].
# Current patch size: [128 112 160].
# Current median shape: [230.49679655 230.49679655 321.20989129]
# Attempting to find 3d_lowres config.
# Current spacing: [1.37275652 0.79988096 0.79988096].
# Current patch size: [128 112 160].
# Current median shape: [223.78329762 223.78329762 311.85426339]
# Attempting to find 3d_lowres config.
# Current spacing: [1.41393922 0.82387739 0.82387739].
# Current patch size: [128 112 160].
# Current median shape: [217.2653375 217.2653375 302.7711295]
# Attempting to find 3d_lowres config.
# Current spacing: [1.4563574  0.84859372 0.84859372].
# Current patch size: [128 112 160].
# Current median shape: [210.93722087 210.93722087 293.95255291]
# Attempting to find 3d_lowres config.
# Current spacing: [1.50004812 0.87405153 0.87405153].
# Current patch size: [128 112 160].
# Current median shape: [204.79341832 204.79341832 285.39082807]
# Attempting to find 3d_lowres config.
# Current spacing: [1.54504956 0.90027307 0.90027307].
# Current patch size: [128 112 160].
# Current median shape: [198.82856148 198.82856148 277.07847386]
# Attempting to find 3d_lowres config.
# Current spacing: [1.59140105 0.92728126 0.92728126].
# Current patch size: [128 112 160].
# Current median shape: [193.03743833 193.03743833 269.00822705]
# Attempting to find 3d_lowres config.
# Current spacing: [1.63914308 0.9550997  0.9550997 ].
# Current patch size: [128 112 160].
# Current median shape: [187.41498867 187.41498867 261.17303597]
# 2D U-Net configuration:
# {'data_identifier': 'nnUNetPlans_2d', 'preprocessor_name': 'DefaultPreprocessor', 'batch_size': 13, 'patch_size': array([448, 576]), 'median_image_size_in_voxels': array([512. , 713.5]), 'spacing': array([0.34960938, 0.34960938]), 'normalization_schemes': ['CTNormalization'], 'use_mask_for_norm': [False], 'UNet_class_name': 'PlainConvUNet', 'UNet_base_num_features': 32, 'n_conv_per_stage_encoder': (2, 2, 2, 2, 2, 2, 2), 'n_conv_per_stage_decoder': (2, 2, 2, 2, 2, 2), 'num_pool_per_axis': [6, 6], 'pool_op_kernel_sizes': [[1, 1], [2, 2], [2, 2], [2, 2], [2, 2], [2, 2], [2, 2]], 'conv_kernel_sizes': [[3, 3], [3, 3], [3, 3], [3, 3], [3, 3], [3, 3], [3, 3]], 'unet_max_num_features': 512, 'resampling_fn_data': 'resample_data_or_seg_to_shape', 'resampling_fn_seg': 'resample_data_or_seg_to_shape', 'resampling_fn_data_kwargs': {'is_seg': False, 'order': 3, 'order_z': 0, 'force_separate_z': None}, 'resampling_fn_seg_kwargs': {'is_seg': True, 'order': 1, 'order_z': 0, 'force_separate_z': None}, 'resampling_fn_probabilities': 'resample_data_or_seg_to_shape', 'resampling_fn_probabilities_kwargs': {'is_seg': False, 'order': 1, 'order_z': 0, 'force_separate_z': None}, 'batch_dice': True}
#
# Using <class 'nnunetv2.imageio.simpleitk_reader_writer.SimpleITKIO'> as reader/writer
# 3D lowres U-Net configuration:
# {'data_identifier': 'nnUNetPlans_3d_lowres', 'preprocessor_name': 'DefaultPreprocessor', 'batch_size': 2, 'patch_size': array([128, 112, 160]), 'median_image_size_in_voxels': [187, 187, 261], 'spacing': array([1.63914308, 0.9550997 , 0.9550997 ]), 'normalization_schemes': ['CTNormalization'], 'use_mask_for_norm': [False], 'UNet_class_name': 'PlainConvUNet', 'UNet_base_num_features': 32, 'n_conv_per_stage_encoder': (2, 2, 2, 2, 2, 2), 'n_conv_per_stage_decoder': (2, 2, 2, 2, 2), 'num_pool_per_axis': [5, 4, 5], 'pool_op_kernel_sizes': [[1, 1, 1], [2, 2, 2], [2, 2, 2], [2, 2, 2], [2, 2, 2], [2, 1, 2]], 'conv_kernel_sizes': [[3, 3, 3], [3, 3, 3], [3, 3, 3], [3, 3, 3], [3, 3, 3], [3, 3, 3]], 'unet_max_num_features': 320, 'resampling_fn_data': 'resample_data_or_seg_to_shape', 'resampling_fn_seg': 'resample_data_or_seg_to_shape', 'resampling_fn_data_kwargs': {'is_seg': False, 'order': 3, 'order_z': 0, 'force_separate_z': None}, 'resampling_fn_seg_kwargs': {'is_seg': True, 'order': 1, 'order_z': 0, 'force_separate_z': None}, 'resampling_fn_probabilities': 'resample_data_or_seg_to_shape', 'resampling_fn_probabilities_kwargs': {'is_seg': False, 'order': 1, 'order_z': 0, 'force_separate_z': None}, 'batch_dice': False, 'next_stage': '3d_cascade_fullres'}
#
# 3D fullres U-Net configuration:
# {'data_identifier': 'nnUNetPlans_3d_fullres', 'preprocessor_name': 'DefaultPreprocessor', 'batch_size': 2, 'patch_size': array([128, 112, 160]), 'median_image_size_in_voxels': array([512. , 512. , 713.5]), 'spacing': array([0.59999996, 0.34960938, 0.34960938]), 'normalization_schemes': ['CTNormalization'], 'use_mask_for_norm': [False], 'UNet_class_name': 'PlainConvUNet', 'UNet_base_num_features': 32, 'n_conv_per_stage_encoder': (2, 2, 2, 2, 2, 2), 'n_conv_per_stage_decoder': (2, 2, 2, 2, 2), 'num_pool_per_axis': [5, 4, 5], 'pool_op_kernel_sizes': [[1, 1, 1], [2, 2, 2], [2, 2, 2], [2, 2, 2], [2, 2, 2], [2, 1, 2]], 'conv_kernel_sizes': [[3, 3, 3], [3, 3, 3], [3, 3, 3], [3, 3, 3], [3, 3, 3], [3, 3, 3]], 'unet_max_num_features': 320, 'resampling_fn_data': 'resample_data_or_seg_to_shape', 'resampling_fn_seg': 'resample_data_or_seg_to_shape', 'resampling_fn_data_kwargs': {'is_seg': False, 'order': 3, 'order_z': 0, 'force_separate_z': None}, 'resampling_fn_seg_kwargs': {'is_seg': True, 'order': 1, 'order_z': 0, 'force_separate_z': None}, 'resampling_fn_probabilities': 'resample_data_or_seg_to_shape', 'resampling_fn_probabilities_kwargs': {'is_seg': False, 'order': 1, 'order_z': 0, 'force_separate_z': None}, 'batch_dice': True}
#
# Plans were saved to /workspace/2024-25ab-fai3-specialisation-project-team-specifix-1/data/segmentation/nnUNet_preprocessed/Dataset063_M_h2/nnUNetPlans.json
# Preprocessing...
# Preprocessing dataset Dataset063_M_h2
# Configuration: 3d_fullres...
# 100%|███████████████████████████████████████████| 58/58 [28:21<00:00, 29.34s/it]

# %%
import os
import torch

os.environ["CUDA_VISIBLE_DEVICES"] = "1"

print(f"Using GPU is CUDA:{os.environ['CUDA_VISIBLE_DEVICES']}")

for i in range(torch.cuda.device_count()):
    info = torch.cuda.get_device_properties(i)
    print(f"CUDA:{i} {info.name}, {info.total_memory / 1024 ** 2}MB")
# Out:
# Using GPU is CUDA:1
# CUDA:0 NVIDIA RTX A6000, 48669.75MB

# %%
# !poetry run nnUNetv2_train 063 3d_fullres 0
# Out:
# Using device: cuda:0
#
# #######################################################################
# Please cite the following paper when using nnU-Net:
# Isensee, F., Jaeger, P. F., Kohl, S. A., Petersen, J., & Maier-Hein, K. H. (2021). nnU-Net: a self-configuring method for deep learning-based biomedical image segmentation. Nature methods, 18(2), 203-211.
# #######################################################################
#
# /root/.cache/pypoetry/virtualenvs/specifix-pAjDTqDi-py3.9/lib/python3.9/site-packages/torch/optim/lr_scheduler.py:28: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn("The verbose parameter is deprecated. Please use get_last_lr() "
#
# This is the configuration used by this training:
# Configuration name: 3d_fullres
#  {'data_identifier': 'nnUNetPlans_3d_fullres', 'preprocessor_name': 'DefaultPreprocessor', 'batch_size': 2, 'patch_size': [128, 112, 160], 'median_image_size_in_voxels': [512.0, 512.0, 713.5], 'spacing': [0.5999999642372131, 0.349609375, 0.349609375], 'normalization_schemes': ['CTNormalization'], 'use_mask_for_norm': [False], 'UNet_class_name': 'PlainConvUNet', 'UNet_base_num_features': 32, 'n_conv_per_stage_encoder': [2, 2, 2, 2, 2, 2], 'n_conv_per_stage_decoder': [2, 2, 2, 2, 2], 'num_pool_per_axis': [5, 4, 5], 'pool_op_kernel_sizes': [[1, 1, 1], [2, 2, 2], [2, 2, 2], [2, 2, 2], [2, 2, 2], [2, 1, 2]], 'conv_kernel_sizes': [[3, 3, 3], [3, 3, 3], [3, 3, 3], [3, 3, 3], [3, 3, 3], [3, 3, 3]], 'unet_max_num_features': 320, 'resampling_fn_data': 'resample_data_or_seg_to_shape', 'resampling_fn_seg': 'resample_data_or_seg_to_shape', 'resampling_fn_data_kwargs': {'is_seg': False, 'order': 3, 'order_z': 0, 'force_separate_z': None}, 'resampling_fn_seg_kwargs': {'is_seg': True, 'order': 1, 'order_z': 0, 'force_separate_z': None}, 'resampling_fn_probabilities': 'resample_data_or_seg_to_shape', 'resampling_fn_probabilities_kwargs': {'is_seg': False, 'order': 1, 'order_z': 0, 'force_separate_z': None}, 'batch_dice': True}
#
# These are the global plan.json settings:
#  {'dataset_name': 'Dataset063_M_h2', 'plans_name': 'nnUNetPlans', 'original_median_spacing_after_transp': [0.5999999642372131, 0.349609375, 0.349609375], 'original_median_shape_after_transp': [512, 512, 622], 'image_reader_writer': 'SimpleITKIO', 'transpose_forward': [0, 1, 2], 'transpose_backward': [0, 1, 2], 'experiment_planner_used': 'ExperimentPlanner', 'label_manager': 'LabelManager', 'foreground_intensity_properties_per_channel': {'0': {'max': 4022.0, 'mean': 2329.197998046875, 'median': 2544.0, 'min': 1132.0, 'percentile_00_5': 1255.0, 'percentile_99_5': 3372.0, 'std': 629.1071166992188}}}
#
# 2024-11-29 11:29:17.629759: unpacking dataset...
# 2024-11-29 11:29:57.184884: unpacking done...
# 2024-11-29 11:29:57.185913: do_dummy_2d_data_aug: False
# 2024-11-29 11:29:57.186844: Creating new 5-fold cross-validation split...
# 2024-11-29 11:29:57.188244: Desired fold for training: 0
# 2024-11-29 11:29:57.188320: This split has 46 training and 12 validation cases.
# 2024-11-29 11:29:57.241801: Unable to plot network architecture:
# 2024-11-29 11:29:57.241937: No module named 'hiddenlayer'
# 2024-11-29 11:29:57.287413:
# 2024-11-29 11:29:57.287560: Epoch 0
# 2024-11-29 11:29:57.287773: Current learning rate: 0.01
# using pin_memory on device 0
# using pin_memory on device 0
# 2024-11-29 11:32:15.184160: train_loss -0.4703
# 2024-11-29 11:32:15.184525: val_loss -0.565
# 2024-11-29 11:32:15.184644: Pseudo dice [0.69]
# 2024-11-29 11:32:15.184764: Epoch time: 137.9 s
# 2024-11-29 11:32:15.184857: Yayy! New best EMA pseudo Dice: 0.69
# 2024-11-29 11:32:17.307408:
# 2024-11-29 11:32:17.307727: Epoch 1
# 2024-11-29 11:32:17.307855: Current learning rate: 0.00999
# 2024-11-29 11:34:26.336001: train_loss -0.6456
# 2024-11-29 11:34:26.337231: val_loss -0.6301
# 2024-11-29 11:34:26.337435: Pseudo dice [0.7338]
# 2024-11-29 11:34:26.337703: Epoch time: 129.03 s
# 2024-11-29 11:34:26.337807: Yayy! New best EMA pseudo Dice: 0.6943
# 2024-11-29 11:34:29.148322:
# 2024-11-29 11:34:29.148631: Epoch 2
# 2024-11-29 11:34:29.148803: Current learning rate: 0.00998
# 2024-11-29 11:36:38.142448: train_loss -0.6699
# 2024-11-29 11:36:38.142827: val_loss -0.6798
# 2024-11-29 11:36:38.142935: Pseudo dice [0.7816]
# 2024-11-29 11:36:38.143093: Epoch time: 129.0 s
# 2024-11-29 11:36:38.143192: Yayy! New best EMA pseudo Dice: 0.7031
# 2024-11-29 11:36:40.574490:
# 2024-11-29 11:36:40.574692: Epoch 3
# 2024-11-29 11:36:40.574851: Current learning rate: 0.00997
# 2024-11-29 11:38:49.105359: train_loss -0.6846
# 2024-11-29 11:38:49.105756: val_loss -0.6604
# 2024-11-29 11:38:49.105874: Pseudo dice [0.7271]
# 2024-11-29 11:38:49.105994: Epoch time: 128.53 s
# 2024-11-29 11:38:49.106084: Yayy! New best EMA pseudo Dice: 0.7055
# 2024-11-29 11:38:51.488925:
# 2024-11-29 11:38:51.489126: Epoch 4
