# %%
import os
import torch

os.environ["CUDA_VISIBLE_DEVICES"] = "0"

print(f"Using GPU is CUDA:{os.environ['CUDA_VISIBLE_DEVICES']}")
print(torch.cuda.is_available())
# Out:
# Using GPU is CUDA:0
# True

# %%
data = {
'nnUNet_raw':'/workspace/2024-25ab-fai3-specialisation-project-team-specifix-1/data/segmentation/nnUNet_raw',
'nnUNet_preprocessed':'/workspace/2024-25ab-fai3-specialisation-project-team-specifix-1/data/segmentation/nnUNet_preprocessed',
'nnUNet_results':'/workspace/2024-25ab-fai3-specialisation-project-team-specifix-1/data/segmentation/nnUNet_results'
}

with open('.env', 'w') as file:
    for key in data:
        file.write(f'{key}={data[key]}\n')

with open('.env', 'r') as file:
    cf = file.read()
print(cf)
# Out:
# nnUNet_raw=/workspace/2024-25ab-fai3-specialisation-project-team-specifix-1/data/segmentation/nnUNet_raw
# nnUNet_preprocessed=/workspace/2024-25ab-fai3-specialisation-project-team-specifix-1/data/segmentation/nnUNet_preprocessed
# nnUNet_results=/workspace/2024-25ab-fai3-specialisation-project-team-specifix-1/data/segmentation/nnUNet_results

# %%
import os
from dotenv import load_dotenv
import subprocess
 
   # Load environment variables from .env file
load_dotenv(override=True)
# Out:
# True

# %%
os.chdir(data['nnUNet_raw'])

# %%
dataset_number = '004'

# %%
# !poetry run nnUNetv2_plan_and_preprocess -d 060 --verify_dataset_integrity -c 3d_fullres
# Out:
# Fingerprint extraction...
# Dataset060_dDU_h2
# Using <class 'nnunetv2.imageio.simpleitk_reader_writer.SimpleITKIO'> as reader/writer
#
# ####################
# verify_dataset_integrity Done.
# If you didn't see any error messages then your dataset is most likely OK!
# ####################
#
# Using <class 'nnunetv2.imageio.simpleitk_reader_writer.SimpleITKIO'> as reader/writer
# 100%|███████████████████████████████████████████| 31/31 [00:42<00:00,  1.36s/it]
# Experiment planning...
# Attempting to find 3d_lowres config.
# Current spacing: [0.61799996 0.38021484 0.38021484].
# Current patch size: [128 128 128].
# Current median shape: [497.08737864 497.08737864 595.14563107]
# Attempting to find 3d_lowres config.
# Current spacing: [0.63653996 0.39162129 0.39162129].
# Current patch size: [128 128 128].
# Current median shape: [482.60910548 482.60910548 577.8112923 ]
# Attempting to find 3d_lowres config.
# Current spacing: [0.65563616 0.40336993 0.40336993].
# Current patch size: [128 128 128].
# Current median shape: [468.55252959 468.55252959 560.98183718]
# Attempting to find 3d_lowres config.
# Current spacing: [0.67530525 0.41547103 0.41547103].
# Current patch size: [128 128 128].
# Current median shape: [454.90536853 454.90536853 544.64256037]
# Attempting to find 3d_lowres config.
# Current spacing: [0.6955644  0.42793516 0.42793516].
# Current patch size: [128 128 128].
# Current median shape: [441.6556976  441.6556976  528.77918483]
# Attempting to find 3d_lowres config.
# Current spacing: [0.71643134 0.44077321 0.44077321].
# Current patch size: [128 128 128].
# Current median shape: [428.79193942 428.79193942 513.37784935]
# Attempting to find 3d_lowres config.
# Current spacing: [0.73792428 0.45399641 0.45399641].
# Current patch size: [128 128 128].
# Current median shape: [416.30285381 416.30285381 498.42509645]
# Attempting to find 3d_lowres config.
# Current spacing: [0.760062  0.4676163 0.4676163].
# Current patch size: [128 128 128].
# Current median shape: [404.17752797 404.17752797 483.90786063]
# Attempting to find 3d_lowres config.
# Current spacing: [0.78286386 0.48164479 0.48164479].
# Current patch size: [128 128 128].
# Current median shape: [392.40536696 392.40536696 469.81345693]
# Attempting to find 3d_lowres config.
# Current spacing: [0.80634978 0.49609413 0.49609413].
# Current patch size: [128 128 128].
# Current median shape: [380.97608443 380.97608443 456.12956983]
# Attempting to find 3d_lowres config.
# Current spacing: [0.83054027 0.51097696 0.51097696].
# Current patch size: [128 128 128].
# Current median shape: [369.87969362 369.87969362 442.84424256]
# Attempting to find 3d_lowres config.
# Current spacing: [0.85545648 0.52630626 0.52630626].
# Current patch size: [128 128 128].
# Current median shape: [359.10649866 359.10649866 429.94586656]
# Attempting to find 3d_lowres config.
# Current spacing: [0.88112018 0.54209545 0.54209545].
# Current patch size: [128 128 128].
# Current median shape: [348.64708608 348.64708608 417.42317142]
# Attempting to find 3d_lowres config.
# Current spacing: [0.90755378 0.55835832 0.55835832].
# Current patch size: [128 128 128].
# Current median shape: [338.49231658 338.49231658 405.26521497]
# Attempting to find 3d_lowres config.
# Current spacing: [0.93478039 0.57510907 0.57510907].
# Current patch size: [128 128 128].
# Current median shape: [328.63331707 328.63331707 393.46137375]
# Attempting to find 3d_lowres config.
# Current spacing: [0.96282381 0.59236234 0.59236234].
# Current patch size: [128 128 128].
# Current median shape: [319.06147288 319.06147288 382.00133374]
# Attempting to find 3d_lowres config.
# Current spacing: [0.99170852 0.61013321 0.61013321].
# Current patch size: [128 128 128].
# Current median shape: [309.76842027 309.76842027 370.8750813 ]
# Attempting to find 3d_lowres config.
# Current spacing: [1.02145978 0.6284372  0.6284372 ].
# Current patch size: [128 128 128].
# Current median shape: [300.7460391  300.7460391  360.07289447]
# Attempting to find 3d_lowres config.
# Current spacing: [1.05210357 0.64729032 0.64729032].
# Current patch size: [128 128 128].
# Current median shape: [291.98644573 291.98644573 349.58533444]
# Attempting to find 3d_lowres config.
# Current spacing: [1.08366668 0.66670903 0.66670903].
# Current patch size: [128 128 128].
# Current median shape: [283.48198614 283.48198614 339.40323732]
# Attempting to find 3d_lowres config.
# Current spacing: [1.11617668 0.6867103  0.6867103 ].
# Current patch size: [128 128 128].
# Current median shape: [275.22522927 275.22522927 329.51770613]
# Attempting to find 3d_lowres config.
# Current spacing: [1.14966198 0.70731161 0.70731161].
# Current patch size: [128 128 128].
# Current median shape: [267.20896045 267.20896045 319.92010304]
# Attempting to find 3d_lowres config.
# Current spacing: [1.18415184 0.72853096 0.72853096].
# Current patch size: [128 128 128].
# Current median shape: [259.4261752  259.4261752  310.60204179]
# Attempting to find 3d_lowres config.
# Current spacing: [1.21967639 0.75038689 0.75038689].
# Current patch size: [128 128 128].
# Current median shape: [251.87007301 251.87007301 301.55538038]
# Attempting to find 3d_lowres config.
# Current spacing: [1.25626668 0.77289849 0.77289849].
# Current patch size: [128 128 128].
# Current median shape: [244.53405146 244.53405146 292.77221396]
# Attempting to find 3d_lowres config.
# Current spacing: [1.29395468 0.79608545 0.79608545].
# Current patch size: [128 128 128].
# Current median shape: [237.41170045 237.41170045 284.24486792]
# Attempting to find 3d_lowres config.
# Current spacing: [1.33277332 0.81996801 0.81996801].
# Current patch size: [128 128 128].
# Current median shape: [230.49679655 230.49679655 275.96589118]
# Attempting to find 3d_lowres config.
# Current spacing: [1.37275652 0.84456705 0.84456705].
# Current patch size: [128 128 128].
# Current median shape: [223.78329762 223.78329762 267.92804969]
# Attempting to find 3d_lowres config.
# Current spacing: [1.41393922 0.86990406 0.86990406].
# Current patch size: [128 128 128].
# Current median shape: [217.2653375  217.2653375  260.12432009]
# Attempting to find 3d_lowres config.
# Current spacing: [1.4563574  0.89600119 0.89600119].
# Current patch size: [128 128 128].
# Current median shape: [210.93722087 210.93722087 252.54788358]
# Attempting to find 3d_lowres config.
# Current spacing: [1.50004812 0.92288122 0.92288122].
# Current patch size: [128 128 128].
# Current median shape: [204.79341832 204.79341832 245.19211998]
# Attempting to find 3d_lowres config.
# Current spacing: [1.54504956 0.95056766 0.95056766].
# Current patch size: [128 128 128].
# Current median shape: [198.82856148 198.82856148 238.05060193]
# Attempting to find 3d_lowres config.
# Current spacing: [1.59140105 0.97908469 0.97908469].
# Current patch size: [128 128 128].
# Current median shape: [193.03743833 193.03743833 231.11708925]
# Attempting to find 3d_lowres config.
# Current spacing: [1.63914308 1.00845723 1.00845723].
# Current patch size: [128 128 128].
# Current median shape: [187.41498867 187.41498867 224.38552354]
# 2D U-Net configuration:
# {'data_identifier': 'nnUNetPlans_2d', 'preprocessor_name': 'DefaultPreprocessor', 'batch_size': 12, 'patch_size': array([512, 512]), 'median_image_size_in_voxels': array([512., 613.]), 'spacing': array([0.36914062, 0.36914062]), 'normalization_schemes': ['CTNormalization'], 'use_mask_for_norm': [False], 'UNet_class_name': 'PlainConvUNet', 'UNet_base_num_features': 32, 'n_conv_per_stage_encoder': (2, 2, 2, 2, 2, 2, 2, 2), 'n_conv_per_stage_decoder': (2, 2, 2, 2, 2, 2, 2), 'num_pool_per_axis': [7, 7], 'pool_op_kernel_sizes': [[1, 1], [2, 2], [2, 2], [2, 2], [2, 2], [2, 2], [2, 2], [2, 2]], 'conv_kernel_sizes': [[3, 3], [3, 3], [3, 3], [3, 3], [3, 3], [3, 3], [3, 3], [3, 3]], 'unet_max_num_features': 512, 'resampling_fn_data': 'resample_data_or_seg_to_shape', 'resampling_fn_seg': 'resample_data_or_seg_to_shape', 'resampling_fn_data_kwargs': {'is_seg': False, 'order': 3, 'order_z': 0, 'force_separate_z': None}, 'resampling_fn_seg_kwargs': {'is_seg': True, 'order': 1, 'order_z': 0, 'force_separate_z': None}, 'resampling_fn_probabilities': 'resample_data_or_seg_to_shape', 'resampling_fn_probabilities_kwargs': {'is_seg': False, 'order': 1, 'order_z': 0, 'force_separate_z': None}, 'batch_dice': True}
#
# Using <class 'nnunetv2.imageio.simpleitk_reader_writer.SimpleITKIO'> as reader/writer
# 3D lowres U-Net configuration:
# {'data_identifier': 'nnUNetPlans_3d_lowres', 'preprocessor_name': 'DefaultPreprocessor', 'batch_size': 2, 'patch_size': array([128, 128, 128]), 'median_image_size_in_voxels': [187, 187, 224], 'spacing': array([1.63914308, 1.00845723, 1.00845723]), 'normalization_schemes': ['CTNormalization'], 'use_mask_for_norm': [False], 'UNet_class_name': 'PlainConvUNet', 'UNet_base_num_features': 32, 'n_conv_per_stage_encoder': (2, 2, 2, 2, 2, 2), 'n_conv_per_stage_decoder': (2, 2, 2, 2, 2), 'num_pool_per_axis': [5, 5, 5], 'pool_op_kernel_sizes': [[1, 1, 1], [2, 2, 2], [2, 2, 2], [2, 2, 2], [2, 2, 2], [2, 2, 2]], 'conv_kernel_sizes': [[3, 3, 3], [3, 3, 3], [3, 3, 3], [3, 3, 3], [3, 3, 3], [3, 3, 3]], 'unet_max_num_features': 320, 'resampling_fn_data': 'resample_data_or_seg_to_shape', 'resampling_fn_seg': 'resample_data_or_seg_to_shape', 'resampling_fn_data_kwargs': {'is_seg': False, 'order': 3, 'order_z': 0, 'force_separate_z': None}, 'resampling_fn_seg_kwargs': {'is_seg': True, 'order': 1, 'order_z': 0, 'force_separate_z': None}, 'resampling_fn_probabilities': 'resample_data_or_seg_to_shape', 'resampling_fn_probabilities_kwargs': {'is_seg': False, 'order': 1, 'order_z': 0, 'force_separate_z': None}, 'batch_dice': False, 'next_stage': '3d_cascade_fullres'}
#
# 3D fullres U-Net configuration:
# {'data_identifier': 'nnUNetPlans_3d_fullres', 'preprocessor_name': 'DefaultPreprocessor', 'batch_size': 2, 'patch_size': array([128, 128, 128]), 'median_image_size_in_voxels': array([512., 512., 613.]), 'spacing': array([0.59999996, 0.36914062, 0.36914062]), 'normalization_schemes': ['CTNormalization'], 'use_mask_for_norm': [False], 'UNet_class_name': 'PlainConvUNet', 'UNet_base_num_features': 32, 'n_conv_per_stage_encoder': (2, 2, 2, 2, 2, 2), 'n_conv_per_stage_decoder': (2, 2, 2, 2, 2), 'num_pool_per_axis': [5, 5, 5], 'pool_op_kernel_sizes': [[1, 1, 1], [2, 2, 2], [2, 2, 2], [2, 2, 2], [2, 2, 2], [2, 2, 2]], 'conv_kernel_sizes': [[3, 3, 3], [3, 3, 3], [3, 3, 3], [3, 3, 3], [3, 3, 3], [3, 3, 3]], 'unet_max_num_features': 320, 'resampling_fn_data': 'resample_data_or_seg_to_shape', 'resampling_fn_seg': 'resample_data_or_seg_to_shape', 'resampling_fn_data_kwargs': {'is_seg': False, 'order': 3, 'order_z': 0, 'force_separate_z': None}, 'resampling_fn_seg_kwargs': {'is_seg': True, 'order': 1, 'order_z': 0, 'force_separate_z': None}, 'resampling_fn_probabilities': 'resample_data_or_seg_to_shape', 'resampling_fn_probabilities_kwargs': {'is_seg': False, 'order': 1, 'order_z': 0, 'force_separate_z': None}, 'batch_dice': True}
#
# Plans were saved to /workspace/2024-25ab-fai3-specialisation-project-team-specifix-1/data/segmentation/nnUNet_preprocessed/Dataset060_dDU_h2/nnUNetPlans.json
# Preprocessing...
# Preprocessing dataset Dataset060_dDU_h2
# Configuration: 3d_fullres...
# 100%|███████████████████████████████████████████| 31/31 [17:01<00:00, 32.95s/it]

# %%
# !poetry run nnUNetv2_train 060 3d_fullres 0
# Out:
# Using device: cuda:0
#
# #######################################################################
# Please cite the following paper when using nnU-Net:
# Isensee, F., Jaeger, P. F., Kohl, S. A., Petersen, J., & Maier-Hein, K. H. (2021). nnU-Net: a self-configuring method for deep learning-based biomedical image segmentation. Nature methods, 18(2), 203-211.
# #######################################################################
#
# /root/.cache/pypoetry/virtualenvs/specifix-pAjDTqDi-py3.9/lib/python3.9/site-packages/torch/optim/lr_scheduler.py:28: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn("The verbose parameter is deprecated. Please use get_last_lr() "
#
# This is the configuration used by this training:
# Configuration name: 3d_fullres
#  {'data_identifier': 'nnUNetPlans_3d_fullres', 'preprocessor_name': 'DefaultPreprocessor', 'batch_size': 2, 'patch_size': [128, 128, 128], 'median_image_size_in_voxels': [512.0, 512.0, 613.0], 'spacing': [0.5999999642372131, 0.369140625, 0.369140625], 'normalization_schemes': ['CTNormalization'], 'use_mask_for_norm': [False], 'UNet_class_name': 'PlainConvUNet', 'UNet_base_num_features': 32, 'n_conv_per_stage_encoder': [2, 2, 2, 2, 2, 2], 'n_conv_per_stage_decoder': [2, 2, 2, 2, 2], 'num_pool_per_axis': [5, 5, 5], 'pool_op_kernel_sizes': [[1, 1, 1], [2, 2, 2], [2, 2, 2], [2, 2, 2], [2, 2, 2], [2, 2, 2]], 'conv_kernel_sizes': [[3, 3, 3], [3, 3, 3], [3, 3, 3], [3, 3, 3], [3, 3, 3], [3, 3, 3]], 'unet_max_num_features': 320, 'resampling_fn_data': 'resample_data_or_seg_to_shape', 'resampling_fn_seg': 'resample_data_or_seg_to_shape', 'resampling_fn_data_kwargs': {'is_seg': False, 'order': 3, 'order_z': 0, 'force_separate_z': None}, 'resampling_fn_seg_kwargs': {'is_seg': True, 'order': 1, 'order_z': 0, 'force_separate_z': None}, 'resampling_fn_probabilities': 'resample_data_or_seg_to_shape', 'resampling_fn_probabilities_kwargs': {'is_seg': False, 'order': 1, 'order_z': 0, 'force_separate_z': None}, 'batch_dice': True}
#
# These are the global plan.json settings:
#  {'dataset_name': 'Dataset060_dDU_h2', 'plans_name': 'nnUNetPlans', 'original_median_spacing_after_transp': [0.5999999642372131, 0.369140625, 0.369140625], 'original_median_shape_after_transp': [512, 512, 620], 'image_reader_writer': 'SimpleITKIO', 'transpose_forward': [0, 1, 2], 'transpose_backward': [0, 1, 2], 'experiment_planner_used': 'ExperimentPlanner', 'label_manager': 'LabelManager', 'foreground_intensity_properties_per_channel': {'0': {'max': 3208.0, 'mean': 1540.91259765625, 'median': 1464.0, 'min': 1216.0, 'percentile_00_5': 1251.0, 'percentile_99_5': 2518.0, 'std': 259.57818603515625}}}
#
# 2024-11-29 11:15:43.959215: unpacking dataset...
# 2024-11-29 11:16:06.291169: unpacking done...
# 2024-11-29 11:16:06.292286: do_dummy_2d_data_aug: False
# 2024-11-29 11:16:06.292969: Creating new 5-fold cross-validation split...
# 2024-11-29 11:16:06.294138: Desired fold for training: 0
# 2024-11-29 11:16:06.294210: This split has 24 training and 7 validation cases.
# 2024-11-29 11:16:06.339926: Unable to plot network architecture:
# 2024-11-29 11:16:06.340030: No module named 'hiddenlayer'
# 2024-11-29 11:16:06.381131:
# 2024-11-29 11:16:06.381263: Epoch 0
# 2024-11-29 11:16:06.381504: Current learning rate: 0.01
# using pin_memory on device 0
# using pin_memory on device 0
# 2024-11-29 11:17:05.226750: train_loss 0.0131
# 2024-11-29 11:17:05.227054: val_loss -0.0346
# 2024-11-29 11:17:05.227154: Pseudo dice [0.0]
# 2024-11-29 11:17:05.227263: Epoch time: 58.85 s
# 2024-11-29 11:17:05.227353: Yayy! New best EMA pseudo Dice: 0.0
# 2024-11-29 11:17:07.229151:
# 2024-11-29 11:17:07.229337: Epoch 1
# 2024-11-29 11:17:07.229508: Current learning rate: 0.00999
# 2024-11-29 11:18:01.601384: train_loss -0.1406
# 2024-11-29 11:18:01.601934: val_loss -0.361
